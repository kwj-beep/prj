# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np
from tabpfn import TabPFNRegressor
from importlib import resources
import os

# %%
def get_df():
    pkl=resources.files('agent').joinpath('df_fs.pkl')
    df=pd.read_pickle(pkl)
    return df

# get_df()
# Out:
# 주요재무정보        매출액  영업이익  영업이익(발표기준)  세전계속사업이익  당기순이익  당기순이익(지배)  당기순이익(비지배)  \
# 날짜
# 2021-03-01  235.0 -14.0       -14.0       7.0    7.0        7.0         NaN
# 2022-03-01  271.0  15.0        15.0      12.0   12.0       15.0        -3.0
# 2023-03-01  419.0  22.0        22.0      14.0   14.0       14.0         NaN
# 2024-03-01  436.0  12.0        12.0      26.0   26.0       26.0         NaN
# 2025-03-01  290.0 -58.0       -58.0    -100.0 -100.0     -101.0         1.0
# ...           ...   ...         ...       ...    ...        ...         ...
# 2024-12-01  613.0   2.0         2.0      19.0   27.0       27.0         NaN
# 2025-12-01  593.0 -75.0       -75.0     -83.0 -125.0     -125.0         NaN
# 2026-12-01    NaN   NaN         NaN       NaN    NaN        NaN         NaN
# 2027-12-01    NaN   NaN         NaN       NaN    NaN        NaN         NaN
# 2028-12-01    NaN   NaN         NaN       NaN    NaN        NaN         NaN
#
# 주요재무정보       자산총계   부채총계   자본총계  ...    자본유보율  EPS(원)  PER(배)  BPS(원)  PBR(배)  \
# 날짜                               ...
# 2021-03-01  546.0  181.0  365.0  ...    57.71    15.0  154.57   792.0    3.02
# 2022-03-01  651.0  268.0  383.0  ...    65.84    33.0  107.72   829.0    4.24
# 2023-03-01  676.0  217.0  460.0  ...    89.35    30.0   75.21   947.0    2.41
# 2024-03-01  638.0  154.0  484.0  ...    99.11    54.0   54.96   998.0    2.96
# 2025-03-01  748.0  253.0  495.0  ...    84.63  -195.0     NaN   933.0    2.36
# ...           ...    ...    ...  ...      ...     ...     ...     ...     ...
# 2024-12-01  867.0  160.0  707.0  ...  1210.53   240.0   14.42  6368.0    0.54
# 2025-12-01  892.0  310.0  582.0  ...   989.16 -1107.0     NaN  5240.0    0.67
# 2026-12-01    NaN    NaN    NaN  ...      NaN     NaN     NaN     NaN     NaN
# 2027-12-01    NaN    NaN    NaN  ...      NaN     NaN     NaN     NaN     NaN
# 2028-12-01    NaN    NaN    NaN  ...      NaN     NaN     NaN     NaN     NaN
#
# 주요재무정보      현금DPS(원)  현금배당수익률  현금배당성향(%)  발행주식수(보통주)    code
# 날짜
# 2021-03-01       0.0      0.0        0.0  45676540.0  060310
# 2022-03-01       0.0      0.0        0.0  46271513.0  060310
# 2023-03-01       0.0      0.0        0.0  48536642.0  060310
# 2024-03-01       0.0      0.0        0.0  48536642.0  060310
# 2025-03-01       0.0      0.0        0.0  53059040.0  060310
# ...              ...      ...        ...         ...     ...
# 2024-12-01       0.0      0.0        0.0  11312236.0  238490
# 2025-12-01       NaN      NaN        NaN  11312236.0  238490
# 2026-12-01       NaN      NaN        NaN         NaN  238490
# 2027-12-01       NaN      NaN        NaN         NaN  238490
# 2028-12-01       NaN      NaN        NaN         NaN  238490
#
# [23032 rows x 34 columns]

# %%
def fit():
    m=TabPFNRegressor()
    return 1


# fit()
