# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np
from tabpfn import TabPFNRegressor
from importlib import resources
import os

# %%
# install 될때는 prj 가 site-packages 에 있기때문에 안해도 된다.
# 지금 테스트 이기 때문에 현재 폴더를 path에등록 해야 한다.
import sys
sys.path.insert(0,r'D:\home\src')

# %%
resources.files('prj').joinpath('df_fs.pkl')
# Out:
# WindowsPath('D:/home/src/prj/df_fs.pkl')

# %%
def tool():
    return 3

# %%
def main():
    m=TabPFNRegressor()
    return 1


# main()
# Out:
# 1

# %% [markdown]
# # run

# %%
if __name__ == "__main__":
    print('hello',main())
# Out:
# hello 1
